# %% [markdown]
# # Video Game Sales
#
# ## Data set: vg-stats
#
# ## Name : Yousef Obeidat
#
# ## Date: 15 NOV 2021

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./vgsales.csv')

# %%
df.keys()
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# ## Which company is the most common video game publisher?

# %%
most_common_publisher = df['Publisher'].mode()
most_common_publisher
# Out:
# 0    Electronic Arts
# dtype: object

# %% [markdown]
# # What’s the most common platform?

# %%
most_common_platform = df['Platform'].mode()
most_common_platform
# Out:
# 0    DS
# dtype: object

# %% [markdown]
# # What about the most common genre ?

# %%
most_common_genre = df['Genre']
most_common_genre.mode()
# Out:
# 0    Action
# dtype: object

# %% [markdown]
# # What are the top 20 highest grossing games?

# %%
top_20_higest_grossing_games = df.sort_values('Global_Sales', ascending=False)
top_20_higest_grossing_games.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# 12    13                   Pokemon Gold/Pokemon Silver       GB  1999.0
# 13    14                                       Wii Fit      Wii  2007.0
# 14    15                                  Wii Fit Plus      Wii  2009.0
# 15    16                            Kinect Adventures!     X360  2010.0
# 16    17                            Grand Theft Auto V      PS3  2013.0
# 17    18                 Grand Theft Auto: San Andreas      PS2  2004.0
# 18    19                             Super Mario World     SNES  1990.0
# 19    20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
#
#            Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                Nintendo     41.49     29.02      3.77
# 1       Platform                Nintendo     29.08      3.58      6.81
# 2         Racing                Nintendo     15.85     12.88      3.79
# 3         Sports                Nintendo     15.75     11.01      3.28
# 4   Role-Playing                Nintendo     11.27      8.89     10.22
# 5         Puzzle                Nintendo     23.20      2.26      4.22
# 6       Platform                Nintendo     11.38      9.23      6.50
# 7           Misc                Nintendo     14.03      9.20      2.93
# 8       Platform                Nintendo     14.59      7.06      4.70
# 9        Shooter                Nintendo     26.93      0.63      0.28
# 10    Simulation                Nintendo      9.07     11.00      1.93
# 11        Racing                Nintendo      9.81      7.57      4.13
# 12  Role-Playing                Nintendo      9.00      6.18      7.20
# 13        Sports                Nintendo      8.94      8.03      3.60
# 14        Sports                Nintendo      9.09      8.59      2.53
# 15          Misc  Microsoft Game Studios     14.97      4.94      0.24
# 16        Action    Take-Two Interactive      7.01      9.27      0.97
# 17        Action    Take-Two Interactive      9.43      0.40      0.41
# 18      Platform                Nintendo     12.78      3.75      3.54
# 19          Misc                Nintendo      4.75      9.26      4.16
#
#     Other_Sales  Global_Sales
# 0          8.46         82.74
# 1          0.77         40.24
# 2          3.31         35.82
# 3          2.96         33.00
# 4          1.00         31.37
# 5          0.58         30.26
# 6          2.90         30.01
# 7          2.85         29.02
# 8          2.26         28.62
# 9          0.47         28.31
# 10         2.75         24.76
# 11         1.92         23.42
# 12         0.71         23.10
# 13         2.15         22.72
# 14         1.79         22.00
# 15         1.67         21.82
# 16         4.14         21.40
# 17        10.57         20.81
# 18         0.55         20.61
# 19         2.05         20.22

# %% [markdown]
# # For North American video game sales, what’s the median?

# %%
median_of_NA_sales = df['NA_Sales']
median_of_NA_sales.median()
# Out:
# 0.08

# %% [markdown]
# # Provide a secondary output showing ten games surrounding the median sales output

# %%
ten_games_surrounding_median_sales = df[df['NA_Sales'] == median_of_NA_sales]
ten_games_surrounding_median_sales.sample(10)
# Out:
#         Rank                                       Name Platform    Year  \
# 7728    7730                                 Demon Gaze      PSV  2013.0
# 4979    4981                             Triple Play 97       PS  1996.0
# 4180    4182           Warhammer 40,000: Dawn of War II       PC  2009.0
# 9072    9074   MTV Music Generator 3: This Is the Remix      PS2  2004.0
# 5135    5137  Barbie Horse Adventures: Blue Ribbon Race      GBA  2003.0
# 4160    4162                          Super Puyo Puyo 2     SNES  1995.0
# 12571  12573                      DuckTales: Remastered     WiiU  2013.0
# 9808    9810                  Macross Triangle Frontier      PSP  2011.0
# 13845  13847                 Haikyu!! Cross Team Match!      3DS  2016.0
# 4459    4461                             Petz: Horsez 2       DS  2007.0
#
#               Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 7728   Role-Playing    Nippon Ichi Software      0.06      0.03      0.08
# 4979         Sports  Electronic Arts Victor      0.21      0.15      0.00
# 4180       Strategy                     THQ      0.00      0.45      0.00
# 9072           Misc             Codemasters      0.07      0.05      0.00
# 5135         Sports     Knowledge Adventure      0.26      0.10      0.00
# 4160         Puzzle                 Compile      0.00      0.00      0.47
# 12571        Action                  Capcom      0.05      0.00      0.00
# 9808         Action      Namco Bandai Games      0.00      0.00      0.12
# 13845     Adventure      Namco Bandai Games      0.00      0.00      0.04
# 4459     Simulation                 Ubisoft      0.41      0.00      0.00
#
#        Other_Sales  Global_Sales
# 7728          0.02          0.20
# 4979          0.03          0.38
# 4180          0.02          0.47
# 9072          0.02          0.14
# 5135          0.01          0.37
# 4160          0.00          0.47
# 12571         0.00          0.06
# 9808          0.00          0.12
# 13845         0.00          0.04
# 4459          0.03          0.44

# %% [markdown]
# # For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America ?

# %%
north_america_mean = df['NA_Sales']
north_america_mean.mean()
na_mean = north_america_mean.mean() 
print(na_mean)

north_america_global_top = df['NA_Sales']
north_america_global_top.iloc()[0]
global_top = north_america_global_top.iloc()[0]
print(global_top)

north_america_standard = df['NA_Sales']
north_america_standard.std()
north_america_std = north_america_standard.std()
print(north_america_std)

north_america_mean_north_america_global_top_distance = global_top - na_mean
north_america_mean_north_america_global_top_distance

north_america_deviations = north_america_mean_north_america_global_top_distance / north_america_std 
north_america_deviations
# Out:
# 0.26466742981082064
# 41.49
# 0.8166830292988796
# 50.47898767479108

# %% [markdown]
# # The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms ?

# %%
other_platforms_m = df[df['Platform'] !='Wii'].Global_Sales.mean()
print("other platforms: ", other_platforms_m)

wii_platform_m = df[df['Platform'] =='Wii'].Global_Sales.mean()
print("Wii platform: ", wii_platform_m)

difference = abs(wii_platform_m - other_platforms_m)
print ("Difference: ", difference)
# Out:
# other platforms:  0.5233896418516336
# Wii platform:  0.6994037735849057
# Difference:  0.17601413173327207

# %% [markdown]
# # Top 5 Racing games ?

# %%
top_Racing_games = df[df['Genre'] == 'Racing'].sort_values('Global_Sales', ascending=False)
top_Racing_games.head(5)
# Out:
#     Rank                    Name Platform    Year   Genre  \
# 2      3          Mario Kart Wii      Wii  2008.0  Racing
# 11    12           Mario Kart DS       DS  2005.0  Racing
# 28    29  Gran Turismo 3: A-Spec      PS2  2001.0  Racing
# 42    43            Mario Kart 7      3DS  2011.0  Racing
# 47    48          Gran Turismo 4      PS2  2004.0  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2                      Nintendo     15.85     12.88      3.79         3.31
# 11                     Nintendo      9.81      7.57      4.13         1.92
# 28  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 42                     Nintendo      4.74      3.91      2.67         0.89
# 47  Sony Computer Entertainment      3.01      0.01      1.10         7.53
#
#     Global_Sales
# 2          35.82
# 11         23.42
# 28         14.98
# 42         12.21
# 47         11.66

# %% [markdown]
# # What newest 5 games ?

# %%
newest_games = df.sort_values('Year',ascending=False)
newest_games.head(5)
# Out:
#         Rank                                              Name Platform  \
# 5957    5959                            Imagine: Makeup Artist       DS
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
# 8293    8295                      Shin Megami Tensei IV: Final      3DS
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
# 8293   2016.0  Role-Playing   Deep Silver      0.03       0.0      0.14
#
#        Other_Sales  Global_Sales
# 5957          0.02          0.29
# 14390         0.00          0.03
# 16241         0.00          0.01
# 16438         0.00          0.01
# 8293          0.00          0.17

# %% [markdown]
# # What is the most popular game in Europe ?

# %%
popular_game_in_europe = df.sort_values('EU_Sales', ascending=False)
popular_game_in_europe.iloc()[0]
# Out:
# Rank                     1
# Name            Wii Sports
# Platform               Wii
# Year                2006.0
# Genre               Sports
# Publisher         Nintendo
# NA_Sales             41.49
# EU_Sales             29.02
# JP_Sales              3.77
# Other_Sales           8.46
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

        assert_equal(most_common_publisher, None)
        assert_equal(most_common_platform, None)
        assert_equal(most_common_genre, None)
        assert_equal(highest_grossing_games.iloc[0].Name, None)
        assert_equal(highest_grossing_games.iloc[19].Name, None)
        assert_equal(north_american_median, None)
        assert_equal(ten_games_surrounding, None)
        assert_equal(popular_game_in_europe.iloc()[0], None)    

    print("Success!!!")

test()
# Out:
# Success!!!
